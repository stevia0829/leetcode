# %%
import pandas as pd
import numpy as np
courseType=pd.DataFrame({
    '课程名称':['工程伦理学','自然辩证法概论','中国特色社会主义理论与实践研究','高级英语听说与高级英语写作','矩阵论','数理统计',
                  '基于MatLab的数字信号处理','线性系统理论','智能控制理论及应用','最优控制理论及实现','计算智能理论及应用',
                  '多智能体系统分布式协同控制及应用','信息融合系统','企业家精神与创新管理','日语（二外）'],
    '学分':[2,1,2,3,3,3,1,3,2,2,2,2,2,2,2]
})
courseType
# Out:
#     学分              课程名称
# 0    2             工程伦理学
# 1    1           自然辩证法概论
# 2    2   中国特色社会主义理论与实践研究
# 3    3     高级英语听说与高级英语写作
# 4    3               矩阵论
# 5    3              数理统计
# 6    1   基于MatLab的数字信号处理
# 7    3            线性系统理论
# 8    2         智能控制理论及应用
# 9    2         最优控制理论及实现
# 10   2         计算智能理论及应用
# 11   2  多智能体系统分布式协同控制及应用
# 12   2            信息融合系统
# 13   2        企业家精神与创新管理
# 14   2            日语（二外）

# %%
courseType['学分'].sum()
# Out:
# 32

# %%
courseType=pd.DataFrame({
    '学分':[2,1,2,3,3,3,1,3,2,2,2,2,2,2,2]
})

# %%
courseType.index = pd.MultiIndex.from_tuples([('公共课', '工程伦理学'), ('公共课', '自然辩证法概论'),('公共课','中国特色社会主义理论与实践研究'),
                                              ('公共课','高级英语听说与高级英语写作'),('基础理论课','矩阵论'),('基础理论课','数理统计'),
                                              ('公共实验课','基于MatLab的数字信号处理'),('专业基础课','线性系统理论'),('专业基础课','智能控制理论及应用'),
                                              ('专业基础课','最优控制理论及实现'),('专业课','计算智能理论及应用'),
                                              ('专业课','多智能体系统分布式协同控制及应用'),
                                              ('专业技术课','信息融合系统'),('专业技术课','企业家精神与创新管理'),
                                              ('综合素养课','日语')],
                                              names=['课程类型','课程名称'])
courseType
# Out:
#                         学分
# 课程类型  课程名称
# 公共课   工程伦理学              2
#       自然辩证法概论            1
#       中国特色社会主义理论与实践研究    2
#       高级英语听说与高级英语写作      3
# 基础理论课 矩阵论                3
#       数理统计               3
# 公共实验课 基于MatLab的数字信号处理    1
# 专业基础课 线性系统理论             3
#       智能控制理论及应用          2
#       最优控制理论及实现          2
# 专业课   计算智能理论及应用          2
#       多智能体系统分布式协同控制及应用   2
# 专业技术课 信息融合系统             2
#       企业家精神与创新管理         2
# 综合素养课 日语                 2

# %%
m_index1=pd.Index([("A","x1"),("A","x2"),("B","y1"),("B","y2"),("B","y3")],name=["class1","class2"])

df1=pd.DataFrame(np.random.randint(1,10,(5,3)),index=m_index1)
df1.to_excel("test1.xls")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-105959290241> in <module>()
#       2
#       3 df1=pd.DataFrame(np.random.randint(1,10,(5,3)),index=m_index1)
# ----> 4 df1.to_excel("test1.xls")
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1422         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1423                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1424                         engine=engine)
#    1425
#    1426     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# ...
